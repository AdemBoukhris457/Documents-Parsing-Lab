# %% [markdown]
# **<center><h1>Assessing Gemini 2.5 Pro’s Performance on Charts and Tables</h1></center>**

# %% [markdown]
# In this notebook, we will test Gemini 2.5 Pro, a reasoning model, to assess its performance in handling charts and tables. The objective is to evaluate how well the model performs across different cases, including varying levels of clarity in axes and complex visual elements. Through this analysis, we aim to identify its strengths and limitations in interpreting structured visual data.

# %% [markdown]
# ## **Table of Contents**
#
# * [1. Install Libraries](#section-one)
# * [2. Import Libraries](#section-two)
# * [3. Define Gemini Client](#section-three)
# * [4. Data Extraction](#section-four)
#     - [Charts Extraction](#subsection-one)
#     - [Tables Extraction](#subsection-two)
# * [5. Conclusion](#section-five)

# %% [markdown]
# # **1. Install Libraries** <a id="section-one"></a>

# %%
# !pip install -U -q google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.7/145.7 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 5.0 MB/s eta 0:00:00

# %% [markdown]
# # **2. Import Libraries** <a id="section-two"></a>

# %%
from google import genai
from google.genai import types
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # **3. Define Gemini Client** <a id="section-three"></a>

# %%
client = genai.Client(api_key="********************************")

# %%
def ask_gemini(image_path, query):
    image = Image.open(image_path)
    
    plt.figure(figsize=(10, 10)) 
    plt.imshow(image)
    plt.axis("off")
    plt.show()
    
    response = client.models.generate_content(
        model="gemini-2.5-pro-exp-03-25",
        contents=[query, image]
    )
    
    print(response.text)

# %% [markdown]
# # **4. Data Extraction** <a id="section-four"></a>

# %% [markdown]
# ## **Charts Extraction** <a id="subsection-one"></a>

# %%
ask_gemini(
    "/kaggle/input/plots-and-tables-images/plot_7.jpg",
    "Extract the data from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the data from the figure represented as a Markdown table.
#
# **Country Net Worth Growth, 2000–21 (GDP Multiple)**
#
# | Country                    | Assets (GDP multiple) | Liabilities (GDP multiple) | Net worth² (GDP multiple) |
# | :------------------------- | --------------------: | -------------------------: | ------------------------: |
# | South Korea                |                   5.2 |                        1.4 |                       3.9 |
# | France                     |                   5.4 |                        1.7 |                       3.6 |
# | New Zealand                |                   3.4 |                        0.2 |                       3.4 |
# | Norway                     |                   4.6 |                        1.4 |                       3.3 |
# | Australia                  |                   5.0 |                        1.5 |                       3.3 |
# ...

# %%
ask_gemini(
    "/kaggle/input/plots-and-tables-images/plot_8.jpg",
    "Extract the data from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the data extracted from the line chart, presented in a markdown table format. The values are estimated based on the visual representation in the graph.
#
# | Series             | 2018   | 2019   | 2020   | 2021   | 2022   | 2023   |
# | :----------------- | :----- | :----- | :----- | :----- | :----- | :----- |
# | Costco             | $100   | ~$128  | ~$155  | $200   | ~$240  | ~$250  |
# | S&P 500            | $100   | ~$105  | ~$120  | ~$180  | ~$150  | ~$175  |
# | S&P 500 Retail     | $100   | ~$95   | ~$105  | ~$170  | ~$140  | ~$155  |
# | S&P Retail Select  | $100   | ~$75   | ~$103  | ~$165  | ~$135  | ~$130  |
#
# **Note:** The values for years 2019, 2020, 2022, and 2023 (and some for 2021) are estimations based on their position relative to the grid lines in the chart. The symbol `~` indicates an approximate value. The values for 2018 and Costco in 2021 appear to align exactly with grid lines.

# %%
ask_gemini(
    "/kaggle/input/tables-and-plots-for-testing/AIIndex_2023_StateofAI_Blog_2.jpg",
    "Extract the data from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the data from the bar chart represented as a Markdown table.
#
# **Estimated Training Costs of Large Models**
#
# | Year | Model                       | Estimated Cost (Millions USD) | Estimation Type |
# | :--- | :-------------------------- | :---------------------------- | :-------------- |
# | 2019 | GPT-2                       | 0.05                          | Low             |
# | 2020 | T5-11B                      | 1.97                          | High            |
# | 2020 | Meena                       | 1.47                          | High            |
# | 2020 | Turing NLG                  | 0.11                          | Low             |
# | 2020 | GPT-3 175B                  | 1.80                          | Mid             |
# | 2020 | DALL-E                      | 0.23                          | Mid             |
# | 2021 | Wu Dao - Wen Yuan           | 0.02                          | Low             |
# ...

# %%
ask_gemini(
    "/kaggle/input/plots-and-tables-images/5-stacked-bar-chart-large-opt (1).png",
    "Extract the data from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the data from the stacked bar chart represented as a markdown table. The values are estimated based on the y-axis scale.
#
# | Strategy    | Product A | Product B | Product C | Product D |
# |-------------|-----------|-----------|-----------|-----------|
# | Strategy 1  | 100       | 100       | 140       | 70        |
# | Strategy 2  | 100       | 150       | 130       | 170       |
# | Strategy 3  | 120       | 80        | 160       | 150       |
# | Strategy 4  | 90        | 80        | 160       | 180       |
# | Strategy 5  | 110       | 105       | 135       | 25        |

# %%
ask_gemini(
    "/kaggle/input/plots-and-tables-images/do-large-vision-language-models-understand-charts-we-found-v0-448ty01q929c1.png",
    "Extract the data from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the data extracted from the stacked bar charts, presented in a Markdown table. The values represent the approximate proportion of each sentence-level error type for the different models on the VisText and Pew datasets, as estimated from the bar segment lengths.
#
# ```markdown
# | Model          | Dataset | Value Error | Label Error | Out-of-context Error | Trend Error | Magnitude Error | Nonsense Error | Grammatical Error |
# | :------------- | :------ | :---------- | :---------- | :------------------- | :---------- | :-------------- | :------------- | :---------------- |
# | GPT-4V         | VisText | 0.15        | 0.17        | 0.03                 | 0.04        | 0.01            | 0.01           | 0.01              |
# | GPT-4V         | Pew     | 0.08        | 0.04        | 0.02                 | 0.01        | 0.01            | 0.04           | 0.01              |
# ...

# %%
ask_gemini(
    "/kaggle/input/plots-and-tables-images/ielts-bar-chart-charlestown-weight-distribution-600x764 (1).png",
    "Extract the data from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the data from the two bar charts presented in markdown table format. The percentages are estimated from the visual representation in the charts.
#
# **Weight Assessment of Inhabitants of Charlestown - 2015**
#
# | Age Range | Underweight (%) | Ideal (%) | Overweight (%) | Obese (%) |
# | :-------- | :-------------- | :-------- | :------------- | :-------- |
# | 20-29     | ~20%            | ~68%      | ~4%            | ~8%       |
# | 30-39     | ~3%             | ~52%      | ~35%           | ~10%      |
# | 40-49     | ~5%             | ~40%      | ~30%           | ~25%      |
# | 50-59     | ~5%             | ~40%      | ~5%            | ~50%      |
# | 60-69     | ~9%             | ~6%       | ~25%           | ~60%      |
#
# **Weight Assessment of Inhabitants of Charlestown - 1955**
#
# | Age Range | Underweight (%) | Ideal (%) | Overweight (%) | Obese (%) |
# | :-------- | :-------------- | :-------- | :------------- | :-------- |
# ...

# %%
ask_gemini(
    "/kaggle/input/plots-and-tables-images/ielts-phone-bar-chart-1.png",
    "Extract the data from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the data from the bar chart represented as a markdown table. The values are estimated from the height of the bars against the Y-axis (Minutes in billions).
#
# **UK Telephone Calls by Category, 1995-2002 (Minutes in Billions)**
#
# | Year | Local - fixed line (billions of minutes) | National and international - fixed line (billions of minutes) | Mobiles (all calls) (billions of minutes) |
# | :--- | :---------------------------------------: | :----------------------------------------------------------: | :--------------------------------------: |
# | 1995 | 72                                        | 37                                                           | 3                                        |
# | 1996 | 80                                        | 41                                                           | 5                                        |
# ...

# %% [markdown]
# ## **Tables Extraction** <a id="subsection-two"></a>

# %%
ask_gemini(
    "/kaggle/input/different-tables-images-testing/other_table.jpg",
    "Extract the table from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the data from the figure presented as a Markdown table.
#
# **Indicateurs du Marché Mondial des Assurances en 2022 (en DT)**
#
# | Pays                     | Assurance Vie - Valeur | Assurance Vie - Part % | Assurance Non-Vie - Valeur | Assurance Non-Vie - Part % | Total     | Part du marché mondial (%) (Primes Nettes/ Primes Mondiales) | Densité d'assurance (D) (Primes Nettes/ Population) | Taux de Pénétration de l'assurance (%) (Primes Nettes/ PIB) |
# | :----------------------- | :--------------------- | :--------------------- | :------------------------- | :------------------------- | :-------- | :--------------------------------------------------------- | :---------------------------------------------------- | :---------------------------------------------------------- |
# ...

# %%
ask_gemini(
    "/kaggle/input/different-tables-images-testing/table_1.jpg",
    "Extract the table from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the Consolidated Statement of Financial Position presented as a Markdown table.
#
# **Consolidated Statement of Financial Position**
# **Year ended 30 June 2019**
# **(J$'000)**
#
# | Item                                       | 2018         | 2019         |
# | :----------------------------------------- | -----------: | -----------: |
# | **Assets**                                 |              |              |
# | **Current Assets**                         |              |              |
# |   Inventories                              | 2,199,273    | 3,225,686    |
# |   Receivables and prepayments              | 2,302,693    | 2,585,519    |
# |   Investment securities                    | 269,530      | 130,385      |
# |   Cash and short-term deposits             | 3,968,075    | 3,974,545    |
# |   *Total Current Assets*                   | *8,739,571*  | *9,916,135*  |
# | **Non-Current Assets**                     |              |              |
# ...

# %%
ask_gemini(
    "/kaggle/input/different-tables-images-testing/table_3.jpg",
    "Extract the table from this figure and represent it as a markdown table. Ensure the table format is clear, structured, and preserves the original data accurately."
)
# Out:
# Okay, here is the table extracted from the image and represented in Markdown format.
#
# **(amounts in millions)**
#
# | Description                                                 | Common Stock Shares (000's) | Common Stock Amount | Additional Paid-in Capital | Accumulated Other Comprehensive Income (Loss) | Retained Earnings | Total Costco Stockholders' Equity | Noncontrolling Interests | Total Equity |
# | :---------------------------------------------------------- | ----------------------------: | --------------------: | ---------------------------: | ---------------------------------------------------: | ------------------: | --------------------------------: | -----------------------: | -------------: |
# ...

# %% [markdown]
# # **5. Conclusion** <a id="section-five"></a>

# %% [markdown]
# <div style="background-color: red; color: white; padding: 10px; border-radius: 5px;">
#     <p>In our evaluation, <b>Gemini 2.5 Pro</b> performed well in understanding <b>charts and tables</b>, accurately extracting structured data. However, it struggles in cases where figures lack a clearly defined and annotated <b>x-axis and y-axis</b>, leading to misinterpretations. Additionally, images with <b>many colors</b> introduce noise, making it difficult for the model to focus on relevant information. These limitations suggest that while the model excels in structured data extraction, improvements are needed for handling ambiguous axes and complex visual elements.</p>
# </div>
